# %% [markdown]
# ## ch2 pandas dataframe index
# 이번 챕터에서는 본격적으로 여러 컬럼과 로우가 들어있는 테이블 데이터를 pandas dataframe을 사용하여 다뤄보겠습니다. 먼저 아래 링크로 들어가서 음악 스트리밍 서비스 spotify가 공개한 2019년 가장 많이 스트리밍 된 트랙 데이터 셋을 다운 받아서 data 폴더 아래에 위치시키겠습니다. 파일 이름이 길어서 "spotify_2019.csv"로 변경하겠습니다.
#
# 데이터 셋: https://www.kaggle.com/datasets/prasertk/spotify-global-2019-moststreamed-tracks

# %% [markdown]
# ### csv 파일로부터 dataframe 생성하기
# pd.read_csv 함수를 사용하면 csv 파일의 데이터를 읽어서 pandas dataframe을 생성합니다. 살펴보면 2019년 가장 많이 스트리밍 된 트랙 1714개에 대해서 아티스트, 스트리밍 횟수 등의 정보를 알려줍니다.

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/spotify_2019.csv", encoding="utf-8")

# %%
df
# Out:
#      Country    Rank                Track_id     Streams  \
# 0     global     1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1     global     2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2     global     3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 3     global     4.0  1rgnBhdG2JDFTbYkYRZAku   764208309
# 4     global     5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359
# ...      ...     ...                     ...         ...
# 1712  global  1713.0  27SdWb2rFzO6GWiYDBTD9j      554971
# 1713  global  1714.0  0kLA41xkWzzYzMIEGFuDkP      544655
# 1714  global  1715.0  79hJaqmVdohltPBNN6BULM      536886
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE      536447
# 1716  global  1717.0  0kCqaybZgYcLYxzZymmBoc      524230
#
#                                              Track Name              Artist  \
# 0                                      Sweet but Psycho             Ava Max
# 1                                               bad guy       Billie Eilish
# ...

# %%
# 이거 습관화 하기!
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1717 entries, 0 to 1716
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            1717 non-null   object
#  1   Rank               1717 non-null   float64
#  2   Track_id           1717 non-null   object
#  3   Streams            1717 non-null   int64
#  4   Track Name         1717 non-null   object
#  5   Artist             1717 non-null   object
#  6   URL                1717 non-null   object
#  7   acousticness       1717 non-null   float64
#  8   danceability       1717 non-null   float64
#  9   energy             1717 non-null   float64
#  10  instrumentalness   1717 non-null   float64
#  11  liveness           1717 non-null   float64
#  12  loudness           1717 non-null   float64
#  13  speechiness        1717 non-null   float64
#  14  valence            1717 non-null   float64
# ...

# %%
# 기초 통계랑 보여줌
df.describe()
# Out:
#               Rank       Streams  acousticness  danceability       energy  \
# count  1717.000000  1.717000e+03   1717.000000   1717.000000  1717.000000
# mean    859.000000  5.166175e+07      0.257652      0.675438     0.624354
# std     495.799523  1.047532e+08      0.256975      0.154163     0.172298
# min       1.000000  5.242300e+05      0.000037      0.151000     0.013700
# 25%     430.000000  1.763026e+06      0.051900      0.584000     0.525000
# 50%     859.000000  9.623926e+06      0.171000      0.694000     0.646000
# 75%    1288.000000  4.829352e+07      0.385000      0.787000     0.747000
# max    1717.000000  1.166186e+09      0.979000      0.974000     0.978000
#
#        instrumentalness     liveness     loudness  speechiness      valence  \
# count       1717.000000  1717.000000  1717.000000  1717.000000  1717.000000
# mean           0.014577     0.174317    -6.477624     0.129967     0.487719
# ...

# %%
df.describe()["tempo"]
# Out:
# count    1717.000000
# mean      122.147556
# std        30.734280
# min        46.489000
# 25%        97.038000
# 50%       120.013000
# 75%       143.027000
# max       207.476000
# Name: tempo, dtype: float64

# %% [markdown]
# ### dataframe에 들어있는 값 일부 확인하기
# df를 그대로 출력해도 jupyter notebook 상에서는 데이터를 확인할 수 있다. df.head나 df.tail을 이용할 경우, 데이터 프레임의 맨 앞 행들 혹은 맨 마지막 행들을 확인할 수 있다.

# %%
df.head()
# Out:
#   Country  Rank                Track_id     Streams        Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736  Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787           bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044           7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309      Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359          Señorita
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# 1  Billie Eilish  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...
# 2  Ariana Grande  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
# 3    Tones and I  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 4   Shawn Mendes  https://open.spotify.com/track/6v3KW9xbzN5yKLt...
#
#    acousticness  danceability  energy  ...  valence    tempo  time_signature  \
# ...

# %%
df.head(n=10)
# Out:
#   Country  Rank                Track_id     Streams         Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736   Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787            bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044            7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309       Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359           Señorita
# 5  global   6.0  5w9c2J52mkdntKOmRLeM2m   715027898          Con Calma
# 6  global   7.0  2VxeLyX666F8uXCJ0dZF8B   714097238            Shallow
# 7  global   8.0  7qEHsqek33rTcFNT9PFqLf   661930419  Someone You Loved
# 8  global   9.0  2dpaYNEQHiRxtZbfNsse99   620829467            Happier
# 9  global  10.0  6MWtB6iiXyIwun0YzU6DFP   615519053               Wow.
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# ...

# %%
df.tail()
# Out:
#      Country    Rank                Track_id  Streams  \
# 1712  global  1713.0  27SdWb2rFzO6GWiYDBTD9j   554971
# 1713  global  1714.0  0kLA41xkWzzYzMIEGFuDkP   544655
# 1714  global  1715.0  79hJaqmVdohltPBNN6BULM   536886
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE   536447
# 1716  global  1717.0  0kCqaybZgYcLYxzZymmBoc   524230
#
#                                              Track Name              Artist  \
# 1712                                      Cheap Thrills                 Sia
# 1713                             HaifischNikez Allstars                  LX
# 1714  Stayin' Alive - From "Saturday Night Fever" So...            Bee Gees
# 1715                 Medley da Gaiola - Dennis DJ Remix    MC Kevin o Chris
# 1716                        Quem Pegou, Pegou - Ao Vivo  Henrique & Juliano
#
#                                                     URL  acousticness  \
# 1712  https://open.spotify.com/track/27SdWb2rFzO6GWi...        0.0472
# ...

# %% [markdown]
# ### dataframe 기본 정보 확인하기
# pandas는 dataframe에 포함된 데이터들을 살펴보는데 편리한 기능들을 제공해줍니다.
#
# 먼저 간단히 데이터 프레임에 행이 몇개고, 컬럼이 몇개인지를 알고 싶으면 df.shape를 사용합니다.

# %%
df.shape
# Out:
# (1717, 24)

# %% [markdown]
# 다음으로 df.info()를 사용하면 데이터 프레임에 어떤 컬럼들이 있고, 각각의 데이터 타입은 어떤지 알 수 있습니다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1717 entries, 0 to 1716
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            1717 non-null   object
#  1   Rank               1717 non-null   float64
#  2   Track_id           1717 non-null   object
#  3   Streams            1717 non-null   int64
#  4   Track Name         1717 non-null   object
#  5   Artist             1717 non-null   object
#  6   URL                1717 non-null   object
#  7   acousticness       1717 non-null   float64
#  8   danceability       1717 non-null   float64
#  9   energy             1717 non-null   float64
#  10  instrumentalness   1717 non-null   float64
#  11  liveness           1717 non-null   float64
#  12  loudness           1717 non-null   float64
#  13  speechiness        1717 non-null   float64
#  14  valence            1717 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Rank       Streams  acousticness  danceability       energy  \
# count  1717.000000  1.717000e+03   1717.000000   1717.000000  1717.000000
# mean    859.000000  5.166175e+07      0.257652      0.675438     0.624354
# std     495.799523  1.047532e+08      0.256975      0.154163     0.172298
# min       1.000000  5.242300e+05      0.000037      0.151000     0.013700
# 25%     430.000000  1.763026e+06      0.051900      0.584000     0.525000
# 50%     859.000000  9.623926e+06      0.171000      0.694000     0.646000
# 75%    1288.000000  4.829352e+07      0.385000      0.787000     0.747000
# max    1717.000000  1.166186e+09      0.979000      0.974000     0.978000
#
#        instrumentalness     liveness     loudness  speechiness      valence  \
# count       1717.000000  1717.000000  1717.000000  1717.000000  1717.000000
# mean           0.014577     0.174317    -6.477624     0.129967     0.487719
# ...

# %% [markdown]
# 다음으로 df.describe()를 이용하여 각 컬럼별로 최소값과 최대값, 평균, 분산 등 기초 통계량을 계산해보겠습니다. 이를 통해서 아주 기본적인 데이터 분석을 진행할 수 있습니다.

# %%
df[["acousticness","energy"]].describe()
# Out:
#        acousticness       energy
# count   1717.000000  1717.000000
# mean       0.257652     0.624354
# std        0.256975     0.172298
# min        0.000037     0.013700
# 25%        0.051900     0.525000
# 50%        0.171000     0.646000
# 75%        0.385000     0.747000
# max        0.979000     0.978000

# %% [markdown]
# ### column 명으로 데이터 조회

# %%
# 시리즈 형태로 나옴
df["acousticness"]
# Out:
# 0       0.0691
# 1       0.3280
# 2       0.5920
# 3       0.6880
# 4       0.0392
#          ...
# 1712    0.0472
# 1713    0.1620
# 1714    0.0700
# 1715    0.7110
# 1716    0.2990
# Name: acousticness, Length: 1717, dtype: float64

# %%
# dataframe 형태로 나옴! 이게 더 안 헷갈림
df[["acousticness"]]
# Out:
#       acousticness
# 0           0.0691
# 1           0.3280
# 2           0.5920
# 3           0.6880
# 4           0.0392
# ...            ...
# 1712        0.0472
# 1713        0.1620
# 1714        0.0700
# 1715        0.7110
# 1716        0.2990
#
# [1717 rows x 1 columns]

# %% [markdown]
# ### dataframe iloc
# iloc은 integer location의 약자로, 정수 인덱스를 사용하여 특정 row와 column을 가져올 수 있습니다.

# %%
df.iloc[10:20]
# Out:
#    Country  Rank                Track_id    Streams  \
# 10  global  11.0  5p7ujcrUXASCNwRaWNHR1C  605653817
# 11  global  12.0  5iwz1NiezX7WWjnCgY5TH4  591435651
# 12  global  13.0  6Qs4SXO9dwPj5GKvVOv8Ki  560659214
# 13  global  14.0  6vBdBCoOhKHiYDDOcorfNo  501130662
# 14  global  15.0  70eFcWOvlMObDhURTqT4Fv  499741532
# 15  global  16.0  6u7jPi22kF8CTQ3rb9DHE7  490147372
# 16  global  17.0  2ksOAxtIxY8yElEWw8RhgK  486837636
# 17  global  18.0  2TH65lNHgvLxCKXM3apjxI  478232047
# 18  global  19.0  2JvzF1RMd7lE3KmFlsyZD8  471425764
# 19  global  20.0  1rqqCSm0Qe4I9rUvWncaom  470921270
#
#                                        Track Name               Artist  \
# 10                                     Without Me               Halsey
# 11                                  Calma - Remix           Pedro Capó
# 12         Dancing With A Stranger (with Normani)            Sam Smith
# 13                    Goodbyes (Feat. Young Thug)          Post Malone
# ...

# %% [markdown]
# ### 연습문제
# 1. 현재 dataframe은 스트리밍 횟수를 기준으로 내림차순 정렬이 된 상태입니다. 스트리밍 횟수 순위가 10위부터 19위인 트랙들의 트랙 이름, 아티스트, 스트리밍 횟수를 가져오세요.

# %%
df.iloc[9:19][["Track_id","Artist","Streams"]]
# Out:
#                   Track_id       Artist    Streams
# 9   6MWtB6iiXyIwun0YzU6DFP  Post Malone  615519053
# 10  5p7ujcrUXASCNwRaWNHR1C       Halsey  605653817
# 11  5iwz1NiezX7WWjnCgY5TH4   Pedro Capó  591435651
# 12  6Qs4SXO9dwPj5GKvVOv8Ki    Sam Smith  560659214
# 13  6vBdBCoOhKHiYDDOcorfNo  Post Malone  501130662
# 14  70eFcWOvlMObDhURTqT4Fv   Ed Sheeran  499741532
# 15  6u7jPi22kF8CTQ3rb9DHE7    Lil Nas X  490147372
# 16  2ksOAxtIxY8yElEWw8RhgK     Anuel AA  486837636
# 17  2TH65lNHgvLxCKXM3apjxI    Bad Bunny  478232047
# 18  2JvzF1RMd7lE3KmFlsyZD8      J. Cole  471425764

# %% [markdown]
# 2. 스트리밍 횟수의 평균, 분산, 표준 편차를 구해보세요. 분포를 파악할 수 있게 히스토그램을 그려보세요.

# %%
df[["Streams"]]
# Out:
#          Streams
# 0     1166185736
# 1     1052358787
# 2      789094044
# 3      764208309
# 4      763064359
# ...          ...
# 1712      554971
# 1713      544655
# 1714      536886
# 1715      536447
# 1716      524230
#
# [1717 rows x 1 columns]

# %%
df.describe()["Streams"][["mean","std"]]
# Out:
# mean    5.166175e+07
# std     1.047532e+08
# Name: Streams, dtype: float64

# %%
# 최적화 
df["Streams"].describe()[["mean","std"]]
# Out:
# mean    5.166175e+07
# std     1.047532e+08
# Name: Streams, dtype: float64

# %%
import numpy as np
df["Streams"].hist(bins=np.arange(0,1000000000,10000000))
# Out:
# <Axes: >

# %%
df[["Streams"]].describe().loc[["mean"]]
# Out:
#            Streams
# mean  5.166175e+07

# %% [markdown]
# 3. 스트리밍 횟수 상위 20개 곡의 평균 템포와 에너지를 구해보세요. 마찬가지로 분포를 파악할 수 있게 히스토그램을 그려보세요.

# %%
df.iloc[0:20][["tempo","energy"]].describe().loc[["mean"]]
# Out:
#           tempo   energy
# mean  117.76225  0.59845

# %%
df[["Streams","energy","tempo"]].iloc[:20].describe().loc[["mean"]]
# Out:
#            Streams   energy      tempo
# mean  6.509250e+08  0.59845  117.76225

# %%
df[["Streams","energy","tempo"]].iloc[:20].hist()
# Out:
# array([[<Axes: title={'center': 'Streams'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'tempo'}>, <Axes: >]], dtype=object)
